# %%
# pretrain simclr_50x2 with MIMIC
# !python ./run.py --mode=train_then_eval --train_mode=pretrain  \
  --train_batch_size=32 --train_epochs=10 --use_tpu=False\
  --learning_rate=1.0 --weight_decay=1e-4 --temperature=0.5 \
  --dataset=mimic_cxr --eval_split=test --train_split=train \
  --resnet_depth=50 --width_multiplier=3 --use_bit=False --image_size=224 \
  --model_dir=./out/models --model_name=simclr_50x2_pretrain
# Out:
# 2024-02-20 23:15:47.397763: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-20 23:15:48.003715: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.2/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# 2024-02-20 23:15:48.003819: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.2/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# 2024-02-20 23:15:48.003828: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.11.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2024-02-20 23:15:49.367635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:15:49.372511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:15:49.372664: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# INFO:tensorflow:Start: 2024-02-20_2315
#
# I0220 23:15:49.372900 139883505526592 run.py:528] Start: 2024-02-20_2315
#
# INFO:tensorflow:GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0220 23:15:49.373162 139883505526592 run.py:529] GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# INFO:tensorflow:
# ===== Stats =====
# I0220 23:15:49.373207 139883505526592 run.py:531]
# ===== Stats =====
# INFO:tensorflow:Dataset name: mimic_cxr
# I0220 23:15:49.373245 139883505526592 run.py:532] Dataset name: mimic_cxr
# INFO:tensorflow:Batch size: 32
# I0220 23:15:49.373282 139883505526592 run.py:533] Batch size: 32
# INFO:tensorflow:Image size: 224
# I0220 23:15:49.373367 139883505526592 run.py:534] Image size: 224
# INFO:tensorflow:Total number of examples:  2048
# I0220 23:15:49.373401 139883505526592 run.py:535] Total number of examples:  2048
# INFO:tensorflow:Total number of classes: 14
# I0220 23:15:49.373434 139883505526592 run.py:536] Total number of classes: 14
# INFO:tensorflow:Total number of training steps: 641
# I0220 23:15:49.373467 139883505526592 run.py:537] Total number of training steps: 641
# INFO:tensorflow:Total number of steps in an epoch: 64
# I0220 23:15:49.373499 139883505526592 run.py:538] Total number of steps in an epoch: 64
# WARNING:tensorflow:From /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py:586: The name tf.estimator.tpu.InputPipelineConfig is deprecated. Please use tf.compat.v1.estimator.tpu.InputPipelineConfig instead.
#
# W0220 23:15:49.374171 139883505526592 module_wrapper.py:149] From /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py:586: The name tf.estimator.tpu.InputPipelineConfig is deprecated. Please use tf.compat.v1.estimator.tpu.InputPipelineConfig instead.
#
# WARNING:tensorflow:Estimator's model_fn (<function build_model_fn.<locals>.model_fn at 0x7f3864019160>) includes params argument, but params are not passed to Estimator.
# W0220 23:15:49.374409 139883505526592 estimator.py:2029] Estimator's model_fn (<function build_model_fn.<locals>.model_fn at 0x7f3864019160>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x2_pretrain_2024-02-20_2315', '_tf_random_seed': None, '_save_summary_steps': 64, '_save_checkpoints_steps': 64, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=64, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1, experimental_allow_per_host_v2_parallel_get_next=False, experimental_feed_hook=None), '_cluster': None}
# I0220 23:15:49.374785 139883505526592 estimator.py:202] Using config: {'_model_dir': '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x2_pretrain_2024-02-20_2315', '_tf_random_seed': None, '_save_summary_steps': 64, '_save_checkpoints_steps': 64, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=64, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1, experimental_allow_per_host_v2_parallel_get_next=False, experimental_feed_hook=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# I0220 23:15:49.374915 139883505526592 tpu_context.py:271] _TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# W0220 23:15:49.375024 139883505526592 tpu_context.py:273] eval_on_tpu ignored because use_tpu is False.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0220 23:15:49.380323 139883505526592 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0220 23:15:52.292968 139883505526592 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# using dataset: train
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0220 23:15:52.681366 139883505526592 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# INFO:tensorflow:Calling model_fn.
# I0220 23:15:53.594575 139883505526592 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Running train on CPU/GPU
# I0220 23:15:53.594777 139883505526592 tpu_estimator.py:3192] Running train on CPU/GPU
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0220 23:15:53.598870 139883505526592 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0220 23:15:53.603342 139883505526592 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:314: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   return tf.layers.conv2d(
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py:561: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W0220 23:15:53.678541 139883505526592 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py:561: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:652: UserWarning: `tf.layers.max_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling2D` instead.
#   inputs = tf.layers.max_pooling2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:735: UserWarning: `tf.layers.average_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.AveragePooling2D` instead.
#   inputs = tf.layers.average_pooling2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/model_util.py:85: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   x = tf.layers.dense(
# INFO:tensorflow:===============Variables to train (begin)===============
# I0220 23:15:55.946190 139883505526592 model.py:99] ===============Variables to train (begin)===============
# INFO:tensorflow:[<tf.Variable 'base_model/conv2d/kernel:0' shape=(7, 7, 3, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_1/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_1/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_1/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_2/kernel:0' shape=(1, 1, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_2/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_2/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_3/kernel:0' shape=(3, 3, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_3/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_3/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_4/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_4/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_4/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_5/kernel:0' shape=(1, 1, 768, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_5/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_5/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_6/kernel:0' shape=(3, 3, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_6/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_6/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_7/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_7/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_7/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_8/kernel:0' shape=(1, 1, 768, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_8/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_8/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_9/kernel:0' shape=(3, 3, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_9/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_9/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_10/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_10/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_10/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_11/kernel:0' shape=(1, 1, 768, 1536) dtype=float32>, <tf.Variable 'base_model/batch_normalization_11/gamma:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_11/beta:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/conv2d_12/kernel:0' shape=(1, 1, 768, 384) dtype=float32>, <tf.Variable 'base_model/batch_normalization_12/gamma:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_12/beta:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/conv2d_13/kernel:0' shape=(3, 3, 384, 384) dtype=float32>, <tf.Variable 'base_model/batch_normalization_13/gamma:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_13/beta:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/conv2d_14/kernel:0' shape=(1, 1, 384, 1536) dtype=float32>, <tf.Variable 'base_model/batch_normalization_14/gamma:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_14/beta:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/conv2d_15/kernel:0' shape=(1, 1, 1536, 384) dtype=float32>, <tf.Variable 'base_model/batch_normalization_15/gamma:0' shape=(384,) dtype=float32>, <tf.Variable 'base_ ...
# I0220 23:15:55.946336 139883505526592 model.py:100] [<tf.Variable 'base_model/conv2d/kernel:0' shape=(7, 7, 3, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_1/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_1/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_1/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_2/kernel:0' shape=(1, 1, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_2/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_2/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_3/kernel:0' shape=(3, 3, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_3/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_3/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_4/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_4/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_4/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_5/kernel:0' shape=(1, 1, 768, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_5/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_5/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_6/kernel:0' shape=(3, 3, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_6/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_6/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_7/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_7/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_7/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_8/kernel:0' shape=(1, 1, 768, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_8/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_8/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_9/kernel:0' shape=(3, 3, 192, 192) dtype=float32>, <tf.Variable 'base_model/batch_normalization_9/gamma:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_9/beta:0' shape=(192,) dtype=float32>, <tf.Variable 'base_model/conv2d_10/kernel:0' shape=(1, 1, 192, 768) dtype=float32>, <tf.Variable 'base_model/batch_normalization_10/gamma:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_10/beta:0' shape=(768,) dtype=float32>, <tf.Variable 'base_model/conv2d_11/kernel:0' shape=(1, 1, 768, 1536) dtype=float32>, <tf.Variable 'base_model/batch_normalization_11/gamma:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_11/beta:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/conv2d_12/kernel:0' shape=(1, 1, 768, 384) dtype=float32>, <tf.Variable 'base_model/batch_normalization_12/gamma:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_12/beta:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/conv2d_13/kernel:0' shape=(3, 3, 384, 384) dtype=float32>, <tf.Variable 'base_model/batch_normalization_13/gamma:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_13/beta:0' shape=(384,) dtype=float32>, <tf.Variable 'base_model/conv2d_14/kernel:0' shape=(1, 1, 384, 1536) dtype=float32>, <tf.Variable 'base_model/batch_normalization_14/gamma:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/batch_normalization_14/beta:0' shape=(1536,) dtype=float32>, <tf.Variable 'base_model/conv2d_15/kernel:0' shape=(1, 1, 1536, 384) dtype=float32>, <tf.Variable 'base_model/batch_normalization_15/gamma:0' shape=(384,) ...
# INFO:tensorflow:================Variables to train (end)================
# I0220 23:15:55.949442 139883505526592 model.py:101] ================Variables to train (end)================
# WARNING:tensorflow:Must enable trace in eager mode.
# W0220 23:15:55.961633 139883505526592 summary_ops_v2.py:1319] Must enable trace in eager mode.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0220 23:15:56.030999 139883505526592 deprecation.py:554] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Done calling model_fn.
# I0220 23:15:59.756310 139883505526592 estimator.py:1175] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I0220 23:15:59.757176 139883505526592 basic_session_run_hooks.py:557] Create CheckpointSaverHook.
# 2024-02-20 23:16:01.560684: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-20 23:16:01.561538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:01.561756: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:01.561914: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:01.926271: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:01.926449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:01.926576: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:01.926677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10103 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# INFO:tensorflow:Graph was finalized.
# I0220 23:16:02.174515 139883505526592 monitored_session.py:240] Graph was finalized.
# 2024-02-20 23:16:02.175900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:02.176094: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:02.176217: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:02.176392: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:02.176521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-20 23:16:02.176626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10103 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2024-02-20 23:16:02.604190: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# INFO:tensorflow:Running local_init_op.
# I0220 23:16:05.269848 139883505526592 session_manager.py:526] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0220 23:16:05.554292 139883505526592 session_manager.py:529] Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# I0220 23:16:14.532820 139883505526592 basic_session_run_hooks.py:627] Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x2_pretrain_2024-02-20_2315/model.ckpt.
# I0220 23:16:14.533078 139883505526592 basic_session_run_hooks.py:632] Saving checkpoints for 0 into /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x2_pretrain_2024-02-20_2315/model.ckpt.

# %%
# FINETUNE
# BASED ON PAPER
# !python ./run.py --mode=train_then_eval --train_mode=finetune \
  --fine_tune_after_block=4 --zero_init_logits_layer=True --rotation_range=15.0 \
  --variable_schema='(?!global_step|(?:.*/|^)Momentum|head)' \
  --global_bn=False --optimizer=adam --learning_rate=1e-2 --weight_decay=1e-6 --train_steps=2500 \
  --train_epochs=10 --train_batch_size=64 --warmup_epochs=0  --use_tpu=False \
  --dataset=mimic_cxr --image_size=128 --eval_split=test --resnet_depth=50 --width_multiplier=1  \
  --checkpoint=./out/models/simclr_50x2_pretrain_2024-02-21_0227 --model_dir=./out/models --model_name=simclr_50x1_finetune
# Out:
# 2024-02-21 10:58:20.024986: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 10:58:20.651802: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.3/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# 2024-02-21 10:58:20.651907: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.3/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# 2024-02-21 10:58:20.651915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.11.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2024-02-21 10:58:22.016923: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.051338: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.051528: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.051869: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 10:58:22.052752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.052943: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.053102: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.474128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.474350: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.474508: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 10:58:22.474637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10103 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# 1 Physical GPUs, 1 Logical GPUs
# INFO:tensorflow:Start: 2024-02-21_1058
#
# I0221 10:58:22.489838 140217330804544 run.py:546] Start: 2024-02-21_1058
#
# INFO:tensorflow:GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0221 10:58:22.490068 140217330804544 run.py:547] GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# INFO:tensorflow:
# ===== Stats =====
# I0221 10:58:22.490141 140217330804544 run.py:549]
# ===== Stats =====
# INFO:tensorflow:Dataset name: mimic_cxr
# I0221 10:58:22.490213 140217330804544 run.py:550] Dataset name: mimic_cxr
# INFO:tensorflow:Batch size: 64
# I0221 10:58:22.490295 140217330804544 run.py:551] Batch size: 64
# INFO:tensorflow:Image size: 128
# I0221 10:58:22.490418 140217330804544 run.py:552] Image size: 128
# INFO:tensorflow:Total number of examples:  12288
# I0221 10:58:22.490455 140217330804544 run.py:553] Total number of examples:  12288
# INFO:tensorflow:Total number of classes: 8
# I0221 10:58:22.490493 140217330804544 run.py:554] Total number of classes: 8
# INFO:tensorflow:Total number of training steps: 2500
# I0221 10:58:22.490527 140217330804544 run.py:555] Total number of training steps: 2500
# INFO:tensorflow:Total number of steps in an epoch: 192
# I0221 10:58:22.490561 140217330804544 run.py:556] Total number of steps in an epoch: 192
# WARNING:tensorflow:From /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py:602: The name tf.estimator.tpu.InputPipelineConfig is deprecated. Please use tf.compat.v1.estimator.tpu.InputPipelineConfig instead.
#
# W0221 10:58:22.491237 140217330804544 module_wrapper.py:149] From /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py:602: The name tf.estimator.tpu.InputPipelineConfig is deprecated. Please use tf.compat.v1.estimator.tpu.InputPipelineConfig instead.
#
# WARNING:tensorflow:Estimator's model_fn (<function build_model_fn.<locals>.model_fn at 0x7f861d8b1160>) includes params argument, but params are not passed to Estimator.
# W0221 10:58:22.491484 140217330804544 estimator.py:2029] Estimator's model_fn (<function build_model_fn.<locals>.model_fn at 0x7f861d8b1160>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x1_finetune_2024-02-21_1058', '_tf_random_seed': None, '_save_summary_steps': 192, '_save_checkpoints_steps': 192, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=192, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1, experimental_allow_per_host_v2_parallel_get_next=False, experimental_feed_hook=None), '_cluster': None}
# I0221 10:58:22.491853 140217330804544 estimator.py:202] Using config: {'_model_dir': '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x1_finetune_2024-02-21_1058', '_tf_random_seed': None, '_save_summary_steps': 192, '_save_checkpoints_steps': 192, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=192, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1, experimental_allow_per_host_v2_parallel_get_next=False, experimental_feed_hook=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# I0221 10:58:22.492067 140217330804544 tpu_context.py:271] _TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# W0221 10:58:22.492184 140217330804544 tpu_context.py:273] eval_on_tpu ignored because use_tpu is False.
# INFO:tensorflow:_____training
# I0221 10:58:22.492233 140217330804544 run.py:652] _____training
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0221 10:58:22.497331 140217330804544 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0221 10:58:25.489536 140217330804544 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# INFO:tensorflow:_____using dataset: train
# I0221 10:58:25.581075 140217330804544 data.py:268] _____using dataset: train
# __________dataset before _map <ShuffleDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.string, name=None))>
# ___________in _map_fn
# ___________image Tensor("args_0:0", dtype=float32)
# __________label Tensor("args_1:0", dtype=float32)
# __________info Tensor("args_2:0", dtype=string)
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0221 10:58:26.499119 140217330804544 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# __________dataset after _map <ParallelMapDataset element_spec=(TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>
# __________dataset after batching <BatchDataset element_spec=(TensorSpec(shape=(64, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(64, 8), dtype=tf.float32, name=None), TensorSpec(shape=(64,), dtype=tf.float32, name=None))>
# INFO:tensorflow:Calling model_fn.
# I0221 10:58:26.780212 140217330804544 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Running train on CPU/GPU
# I0221 10:58:26.780444 140217330804544 tpu_estimator.py:3192] Running train on CPU/GPU
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:314: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   return tf.layers.conv2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:164: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   inputs = tf.layers.batch_normalization(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:652: UserWarning: `tf.layers.max_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling2D` instead.
#   inputs = tf.layers.max_pooling2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:735: UserWarning: `tf.layers.average_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.AveragePooling2D` instead.
#   inputs = tf.layers.average_pooling2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/model_util.py:85: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   x = tf.layers.dense(
# INFO:tensorflow:===============Variables to train (begin)===============
# I0221 10:58:28.672058 140217330804544 model.py:100] ===============Variables to train (begin)===============
# INFO:tensorflow:[<tf.Variable 'head_supervised/linear_layer/dense/kernel:0' shape=(2048, 8) dtype=float32>, <tf.Variable 'head_supervised/linear_layer/dense/bias:0' shape=(8,) dtype=float32>]
# I0221 10:58:28.672204 140217330804544 model.py:101] [<tf.Variable 'head_supervised/linear_layer/dense/kernel:0' shape=(2048, 8) dtype=float32>, <tf.Variable 'head_supervised/linear_layer/dense/bias:0' shape=(8,) dtype=float32>]
# INFO:tensorflow:================Variables to train (end)================
# I0221 10:58:28.672317 140217330804544 model.py:102] ================Variables to train (end)================
# WARNING:tensorflow:Must enable trace in eager mode.
# W0221 10:58:28.683415 140217330804544 summary_ops_v2.py:1319] Must enable trace in eager mode.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0221 10:58:28.752808 140217330804544 deprecation.py:554] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Head restoring ...
# I0221 10:58:28.847404 140217330804544 model.py:238] Head restoring ...
# INFO:tensorflow:training_loop marked as finished
# I0221 10:58:29.541991 140217330804544 error_handling.py:115] training_loop marked as finished
# WARNING:tensorflow:Reraising captured error
# W0221 10:58:29.542149 140217330804544 error_handling.py:149] Reraising captured error
# Traceback (most recent call last):
#   File "/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py", line 696, in <module>
#     app.run(main)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py", line 671, in main
#     estimator.train(train_input_fn, max_steps=train_steps)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3104, in train
#     rendezvous.raise_errors()
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/error_handling.py", line 150, in raise_errors
#     six.reraise(typ, value, traceback)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/six.py", line 703, in reraise
#     raise value
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3094, in train
#     return super(TPUEstimator, self).train(
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 360, in train
#     loss = self._train_model(input_fn, hooks, saving_listeners)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1186, in _train_model
#     return self._train_model_default(input_fn, hooks, saving_listeners)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1214, in _train_model_default
#     estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 2935, in _call_model_fn
#     return super(TPUEstimator, self)._call_model_fn(features, labels, mode,
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1174, in _call_model_fn
#     model_fn_results = self._model_fn(features=features, **kwargs)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3193, in _model_fn
#     estimator_spec = model_fn_wrapper.call_without_tpu(
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 1715, in call_without_tpu
#     return self._call_model_fn(features, labels, is_export_mode=is_export_mode)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 2070, in _call_model_fn
#     return estimator_spec.as_estimator_spec()
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 384, in as_estimator_spec
#     scaffold = self.scaffold_fn() if self.scaffold_fn else None
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/tmp/__autograph_generated_filemi8enzqw.py", line 12, in tf__scaffold_fn
#     ag__.converted_call(ag__.ld(tf).train.init_from_checkpoint, (ag__.ld(checkpoint_dir), {ag__.ld(v).op.name: ag__.ld(v).op.name for v in ag__.converted_call(ag__.ld(tf).global_variables, (ag__.ld(FLAGS).variable_schema,), None, fscope)}), None, fscope)
# ValueError: in user code:
#
#     File "/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/model.py", line 253, in scaffold_fn  *
#         tf.train.init_from_checkpoint(
#
#     ValueError: Assignment map with scope only name  should map to scope only beta1_power. Should be 'scope/': 'other_scope/'.

# %%
# FINETUNE
# BASED ON PAPER
# !python ./run.py --mode=train_then_eval --train_mode=finetune \
  --fine_tune_after_block=4 --zero_init_logits_layer=True --rotation_range=15.0 \
  --variable_schema='(?!global_step|(?:.*/|^)Momentum|head)' \
  --global_bn=False --optimizer=adam --learning_rate=1e-2 --weight_decay=1e-6 --train_steps=2500 \
  --train_epochs=10 --train_batch_size=64 --warmup_epochs=0  --use_tpu=False \
  --dataset=mimic_cxr --image_size=128 --eval_split=test --resnet_depth=50 --width_multiplier=1  \
  --checkpoint=./base-models/simclr/r50_1x_sk0 --model_dir=./out/models --model_name=simclr_50x1_finetune
# Out:
# 2024-02-21 11:02:02.908754: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 11:02:03.528135: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.3/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# 2024-02-21 11:02:03.528227: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.3/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# 2024-02-21 11:02:03.528236: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.11.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2024-02-21 11:02:04.910784: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:04.945853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:04.946059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:04.946427: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 11:02:04.947694: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:04.947886: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:04.948020: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:05.374672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:05.374880: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:05.375036: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-02-21 11:02:05.375165: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10103 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
# 1 Physical GPUs, 1 Logical GPUs
# INFO:tensorflow:Start: 2024-02-21_1102
#
# I0221 11:02:05.390666 140316199843648 run.py:546] Start: 2024-02-21_1102
#
# INFO:tensorflow:GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0221 11:02:05.390854 140316199843648 run.py:547] GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# INFO:tensorflow:
# ===== Stats =====
# I0221 11:02:05.390900 140316199843648 run.py:549]
# ===== Stats =====
# INFO:tensorflow:Dataset name: mimic_cxr
# I0221 11:02:05.390939 140316199843648 run.py:550] Dataset name: mimic_cxr
# INFO:tensorflow:Batch size: 64
# I0221 11:02:05.390978 140316199843648 run.py:551] Batch size: 64
# INFO:tensorflow:Image size: 128
# I0221 11:02:05.391064 140316199843648 run.py:552] Image size: 128
# INFO:tensorflow:Total number of examples:  12288
# I0221 11:02:05.391100 140316199843648 run.py:553] Total number of examples:  12288
# INFO:tensorflow:Total number of classes: 8
# I0221 11:02:05.391137 140316199843648 run.py:554] Total number of classes: 8
# INFO:tensorflow:Total number of training steps: 2500
# I0221 11:02:05.391170 140316199843648 run.py:555] Total number of training steps: 2500
# INFO:tensorflow:Total number of steps in an epoch: 192
# I0221 11:02:05.391204 140316199843648 run.py:556] Total number of steps in an epoch: 192
# WARNING:tensorflow:From /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py:602: The name tf.estimator.tpu.InputPipelineConfig is deprecated. Please use tf.compat.v1.estimator.tpu.InputPipelineConfig instead.
#
# W0221 11:02:05.391859 140316199843648 module_wrapper.py:149] From /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py:602: The name tf.estimator.tpu.InputPipelineConfig is deprecated. Please use tf.compat.v1.estimator.tpu.InputPipelineConfig instead.
#
# WARNING:tensorflow:Estimator's model_fn (<function build_model_fn.<locals>.model_fn at 0x7f9d2299c1f0>) includes params argument, but params are not passed to Estimator.
# W0221 11:02:05.392088 140316199843648 estimator.py:2029] Estimator's model_fn (<function build_model_fn.<locals>.model_fn at 0x7f9d2299c1f0>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x1_finetune_2024-02-21_1102', '_tf_random_seed': None, '_save_summary_steps': 192, '_save_checkpoints_steps': 192, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=192, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1, experimental_allow_per_host_v2_parallel_get_next=False, experimental_feed_hook=None), '_cluster': None}
# I0221 11:02:05.392559 140316199843648 estimator.py:202] Using config: {'_model_dir': '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./out/models/simclr_50x1_finetune_2024-02-21_1102', '_tf_random_seed': None, '_save_summary_steps': 192, '_save_checkpoints_steps': 192, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=192, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None, eval_training_input_configuration=2, experimental_host_call_every_n_steps=1, experimental_allow_per_host_v2_parallel_get_next=False, experimental_feed_hook=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# I0221 11:02:05.392725 140316199843648 tpu_context.py:271] _TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# W0221 11:02:05.392859 140316199843648 tpu_context.py:273] eval_on_tpu ignored because use_tpu is False.
# INFO:tensorflow:_____training
# I0221 11:02:05.392959 140316199843648 run.py:652] _____training
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0221 11:02:05.398095 140316199843648 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/training/training_util.py:396: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0221 11:02:08.323863 140316199843648 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# INFO:tensorflow:_____using dataset: train
# I0221 11:02:08.414694 140316199843648 data.py:268] _____using dataset: train
# __________dataset before _map <ShuffleDataset element_spec=(TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), TensorSpec(shape=<unknown>, dtype=tf.string, name=None))>
# ___________in _map_fn
# ___________image Tensor("args_0:0", dtype=float32)
# __________label Tensor("args_1:0", dtype=float32)
# __________info Tensor("args_2:0", dtype=string)
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0221 11:02:09.315347 140316199843648 deprecation.py:350] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# __________dataset after _map <ParallelMapDataset element_spec=(TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(8,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>
# __________dataset after batching <BatchDataset element_spec=(TensorSpec(shape=(64, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(64, 8), dtype=tf.float32, name=None), TensorSpec(shape=(64,), dtype=tf.float32, name=None))>
# INFO:tensorflow:Calling model_fn.
# I0221 11:02:09.592593 140316199843648 estimator.py:1173] Calling model_fn.
# INFO:tensorflow:Running train on CPU/GPU
# I0221 11:02:09.592784 140316199843648 tpu_estimator.py:3192] Running train on CPU/GPU
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:314: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   return tf.layers.conv2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:164: UserWarning: `tf.layers.batch_normalization` is deprecated and will be removed in a future version. Please use `tf.keras.layers.BatchNormalization` instead. In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
#   inputs = tf.layers.batch_normalization(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:652: UserWarning: `tf.layers.max_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.MaxPooling2D` instead.
#   inputs = tf.layers.max_pooling2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/resnet.py:735: UserWarning: `tf.layers.average_pooling2d` is deprecated and will be removed in a future version. Please use `tf.keras.layers.AveragePooling2D` instead.
#   inputs = tf.layers.average_pooling2d(
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/model_util.py:85: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   x = tf.layers.dense(
# INFO:tensorflow:===============Variables to train (begin)===============
# I0221 11:02:11.480691 140316199843648 model.py:100] ===============Variables to train (begin)===============
# INFO:tensorflow:[<tf.Variable 'head_supervised/linear_layer/dense/kernel:0' shape=(2048, 8) dtype=float32>, <tf.Variable 'head_supervised/linear_layer/dense/bias:0' shape=(8,) dtype=float32>]
# I0221 11:02:11.480836 140316199843648 model.py:101] [<tf.Variable 'head_supervised/linear_layer/dense/kernel:0' shape=(2048, 8) dtype=float32>, <tf.Variable 'head_supervised/linear_layer/dense/bias:0' shape=(8,) dtype=float32>]
# INFO:tensorflow:================Variables to train (end)================
# I0221 11:02:11.480950 140316199843648 model.py:102] ================Variables to train (end)================
# WARNING:tensorflow:Must enable trace in eager mode.
# W0221 11:02:11.491901 140316199843648 summary_ops_v2.py:1319] Must enable trace in eager mode.
# WARNING:tensorflow:From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0221 11:02:11.561596 140316199843648 deprecation.py:554] From /home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Head restoring ...
# I0221 11:02:11.655446 140316199843648 model.py:238] Head restoring ...
# INFO:tensorflow:training_loop marked as finished
# I0221 11:02:11.726445 140316199843648 error_handling.py:115] training_loop marked as finished
# WARNING:tensorflow:Reraising captured error
# W0221 11:02:11.726641 140316199843648 error_handling.py:149] Reraising captured error
# Traceback (most recent call last):
#   File "/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py", line 696, in <module>
#     app.run(main)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/absl/app.py", line 308, in run
#     _run_main(main, args)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/absl/app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./run.py", line 671, in main
#     estimator.train(train_input_fn, max_steps=train_steps)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3104, in train
#     rendezvous.raise_errors()
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/error_handling.py", line 150, in raise_errors
#     six.reraise(typ, value, traceback)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/six.py", line 703, in reraise
#     raise value
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3094, in train
#     return super(TPUEstimator, self).train(
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 360, in train
#     loss = self._train_model(input_fn, hooks, saving_listeners)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1186, in _train_model
#     return self._train_model_default(input_fn, hooks, saving_listeners)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1214, in _train_model_default
#     estimator_spec = self._call_model_fn(features, labels, ModeKeys.TRAIN,
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 2935, in _call_model_fn
#     return super(TPUEstimator, self)._call_model_fn(features, labels, mode,
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/estimator.py", line 1174, in _call_model_fn
#     model_fn_results = self._model_fn(features=features, **kwargs)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 3193, in _model_fn
#     estimator_spec = model_fn_wrapper.call_without_tpu(
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 1715, in call_without_tpu
#     return self._call_model_fn(features, labels, is_export_mode=is_export_mode)
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 2070, in _call_model_fn
#     return estimator_spec.as_estimator_spec()
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow_estimator/python/estimator/tpu/tpu_estimator.py", line 384, in as_estimator_spec
#     scaffold = self.scaffold_fn() if self.scaffold_fn else None
#   File "/home/payam/miniconda3/envs/tf2-gpu/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/tmp/__autograph_generated_file8gxweygo.py", line 12, in tf__scaffold_fn
#     ag__.converted_call(ag__.ld(tf).train.init_from_checkpoint, (ag__.ld(checkpoint_dir), {ag__.ld(v).op.name: ag__.ld(v).op.name for v in ag__.converted_call(ag__.ld(tf).global_variables, (ag__.ld(FLAGS).variable_schema,), None, fscope)}), None, fscope)
# ValueError: in user code:
#
#     File "/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/code/pretrain/model.py", line 253, in scaffold_fn  *
#         tf.train.init_from_checkpoint(
#
#     ValueError: Couldn't find 'checkpoint' file or checkpoints in given directory /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/./base-models/remedis/cxr-50x1-remedis-s
