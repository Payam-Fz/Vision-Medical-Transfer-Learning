# %%
# !python finetuning3.py --dataset=MIMIC-CXR \
    --model_name=simclr_50x2 --base_model_path='./out/models/simclr_50x2_pretrain_2024-02-21_0227' \
    --image_size=448 --epochs=10 --batch_size=32 --learning_rate=0.1
# Out:
# 2024-02-21 11:11:41.007713: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 11:11:41.533876: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.3/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# ...

# %%
# !python finetuning3.py --dataset=MIMIC-CXR \
    --model_name=simclr_50x2 --base_model_path='./base-models/remedis/cxr-50x1-remedis-m' \
    --image_size=448 --epochs=10 --batch_size=32 --learning_rate=0.1
# Out:
# 2024-02-21 11:13:07.662813: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-21 11:13:08.190952: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-12.3/lib64:/home/payam/miniconda3/envs/tf2-gpu/lib/
# ...
