# %% [markdown]
# # VGG16

# %% [markdown]
# ### Best with head only

# %%
# !python ../../neural_nets/vgg16.py \
    --ouput_name=vgg16-eval-0unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vgg16_final/vgg16-gradual-fix-color_2024-04-03_0941/0_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-10 15:09:15.328157: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 1 block unfrozen

# %%
# !python ../../neural_nets/vgg16.py \
    --ouput_name=vgg16-eval-1unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vgg16_final/vgg16-gradual-1-4_2024-04-04_1118/1_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:14:12.318917: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 2 block unfrozen

# %%
# !python ../../neural_nets/vgg16.py \
    --ouput_name=vgg16-eval-1unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vgg16_final/vgg16-gradual-1-4_2024-04-04_1118/2_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:16:18.564291: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 3 block unfrozen

# %%
# !python ../../neural_nets/vgg16.py \
    --ouput_name=vgg16-eval-3unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vgg16_final/vgg16-gradual-1-4_2024-04-04_1118/3_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:20:24.252757: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 4 block unfrozen

# %%
# !python ../../neural_nets/vgg16.py \
    --ouput_name=vgg16-eval-4unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vgg16_final/vgg16-gradual-1-4_2024-04-04_1118/4_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:22:25.820077: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with all unfrozen

# %%
# !python ../../neural_nets/vgg16.py \
    --ouput_name=vgg16-eval-5unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vgg16_final/vgg16-all-unfrozen_2024-04-22_2202/5_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-25 14:47:10.694914: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Resnet50

# %% [markdown]
# ### Best with head only

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-0unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/0_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-10 20:53:13.365281: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 1 block unfrozen

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-1unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/1_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:24:29.279251: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 2 block unfrozen

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-2unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/2_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:26:10.344338: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 3 block unfrozen

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-3unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/3_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 08:31:48.221971: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with 4 block unfrozen

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-4unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/4_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-25 14:44:20.490469: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-4unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/4_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 08:44:17.051258: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with all unfrozen

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-eval-5unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-retry_2024-04-05_1113/5_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 08:48:07.259841: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # ViT

# %% [markdown]
# ### Best with head only

# %%
# !python ../../neural_nets/vit_hf.py \
    --ouput_name=vit-eval-0unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out/vit-gradual-hf_2024-04-10_0251/0_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-10 21:07:38.876315: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ### Best with all unfrozen

# %%
# !python ../../neural_nets/vit_hf.py \
    --ouput_name=vit-eval-allunfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vit_final/vit-gradual-hf_2024-04-10_0251/1_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-25 14:50:01.448448: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/vit_hf.py \
    --ouput_name=vit-eval-allunfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vit_final/vit-gradual-hf_2024-04-10_0251/1_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 08:34:34.907493: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Augment

# %% [markdown]
# ## Resnet-aug

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-aug-eval-0unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-augment_2024-04-05_1320/0_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 08:37:34.010463: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-aug-eval-1unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-augment_2024-04-05_1320/1_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-22 12:45:40.396443: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-aug-eval-2unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-augment_2024-04-05_1320/2_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 01:51:43.556888: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-aug-eval-3unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-augment_2024-04-05_1320/3_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 01:54:25.202279: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-aug-eval-4unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-augment_2024-04-05_1320/4_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 01:57:06.481282: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/resnet50.py \
    --ouput_name=resnet50-aug-eval-5unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/resnet50_final/resnet50-augment_2024-04-05_1320/5_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 01:59:46.308800: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## ViT-aug

# %%
# !python ../../neural_nets/vit_hf.py \
    --ouput_name=vit-aug-eval-0unfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vit_final/vit-gradual-hf-augment_2024-04-13_1233/0_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 02:02:27.061252: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python ../../neural_nets/vit_hf.py \
    --ouput_name=vit-aug-eval-allunfreeze \
    --image_size=224 --batch_size=32 --train_size=2 \
    --mode=eval --min_unfreeze_blocks=0 --max_unfreeze_blocks=0 \
    --load_checkpoint=./out_archive/vit_final/vit-gradual-hf-augment_2024-04-13_1233/1_unfrozen_block/model/checkpoints
# Out:
# setting cwd to '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation'
# ['/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode/neural_nets', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python39.zip', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/lib-dynload', '/home/payam/miniconda3/envs/tf2-gpu-hf/lib/python3.9/site-packages', '/mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation/mycode']
# /mnt/samba/research/shield/projects/payamfz/medical-ssl-segmentation
# 2024-04-24 02:05:21.179497: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
